# %% [markdown]
# Details on variables can be found here: https://www2.stetson.edu/~jrasp/data/CollegeScorecard_variables.pdf

# %%
# Ok, third time's the charm!

# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('CollegeScorecard.csv', encoding = "ISO-8859-1")
df.head()
# Out:
#    UNITID                               INSTNM        CITY STABBR  CONTROL  \
# 0  100654             Alabama A & M University      Normal     AL        1
# 1  100663  University of Alabama at Birmingham  Birmingham     AL        1
# 2  100690                   Amridge University  Montgomery     AL        2
# 3  100706  University of Alabama in Huntsville  Huntsville     AL        1
# 4  100724             Alabama State University  Montgomery     AL        1
#
#    CCBASIC  ADM_RATE  SAT_AVG     UGDS  UGDS_WHITE  ...  NPT4_PRIV  COSTT4_A  \
# 0     18.0    0.5256    827.0   4206.0      0.0333  ...        NaN   21475.0
# 1     15.0    0.8569   1107.0  11383.0      0.5922  ...        NaN   20621.0
# 2     20.0       NaN      NaN    291.0      0.2990  ...    12992.0   16370.0
# 3     16.0    0.8203   1219.0   5451.0      0.6988  ...        NaN   21107.0
# 4     19.0    0.5326    851.0   4811.0      0.0158  ...        NaN   18184.0
#
#    TUITFTE  INEXPFTE  PFTFAC  PCTPELL  C150_4  PFTFTUG1_EF  RET_FT4  PCTFLOAN
# 0   9427.0    7437.0  0.8967   0.7356  0.3525       0.8578   0.6595    0.8284
# 1   9899.0   17920.0  0.9072   0.3460  0.5554       0.5041   0.8288    0.5214
# 2  12459.0    5532.0  0.6000   0.6801  0.2222       0.5000   0.0000    0.7795
# 3   8956.0   10211.0  0.6221   0.3072  0.4614       0.4750   0.7696    0.4596
# 4   7733.0    7618.0  0.6539   0.7347  0.2632       0.8812   0.5725    0.7554
#
# [5 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7703 entries, 0 to 7702
# Data columns (total 30 columns):
# UNITID         7703 non-null int64
# INSTNM         7703 non-null object
# CITY           7703 non-null object
# STABBR         7703 non-null object
# CONTROL        7703 non-null int64
# CCBASIC        7282 non-null float64
# ADM_RATE       2198 non-null float64
# SAT_AVG        1304 non-null float64
# UGDS           6990 non-null float64
# UGDS_WHITE     6990 non-null float64
# UGDS_BLACK     6990 non-null float64
# UGDS_HISP      6990 non-null float64
# UGDS_ASIAN     6990 non-null float64
# UGDS_AIAN      6990 non-null float64
# UGDS_NHPI      6990 non-null float64
# UGDS_2MOR      6990 non-null float64
# UGDS_NRA       6990 non-null float64
# UGDS_UNKN      6990 non-null float64
# PPTUG_EF       6969 non-null float64
# NPT4_PUB       1911 non-null float64
# NPT4_PRIV      4688 non-null float64
# COSTT4_A       4030 non-null float64
# TUITFTE        7270 non-null float64
# INEXPFTE       7270 non-null float64
# PFTFAC         4045 non-null float64
# PCTPELL        6966 non-null float64
# C150_4         2481 non-null float64
# PFTFTUG1_EF    3664 non-null float64
# RET_FT4        2293 non-null float64
# PCTFLOAN       6966 non-null float64
# dtypes: float64(25), int64(2), object(3)
# memory usage: 1.8+ MB

# %%
sns.regplot(x='ADM_RATE', y='SAT_AVG', data=df, fit_reg=False)

# %%
sns.regplot(x='ADM_RATE', y='SAT_AVG', data=df, fit_reg=True, scatter_kws={"alpha": 0.2})

# %%
sns.jointplot(x='ADM_RATE', y='SAT_AVG', kind='kde', data=df)

# %%
df['CONTROL'] = df['CONTROL'].replace({1: 'Public',
                                      2: 'Private nonprofit',
                                      3: 'Private for-profit'})

# %%
sns.FacetGrid(df, col='CONTROL').map(plt.scatter, 'ADM_RATE', 'SAT_AVG', alpha=.2).add_legend()
